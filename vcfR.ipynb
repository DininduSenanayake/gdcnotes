# %%
library(vcfR)

# %%
vcf <- read.vcfR ("/home/dsen018/VCF/SRR2584866_final_variants.vcf", verbose = FALSE)

# %%
reference <- ape::read.dna ("/home/dsen018/VCF/ecoli_rel606.fasta" , format = "fasta")

# %%
chrom <- create.chromR(name = 'SuperContig' , vcf = vcf , seq = reference)
# Out:
# Names in vcf:
#
#   CP000819.1
#
# Names of sequences:
#
#   CP000819.1 Escherichia coli B str. REL606, complete genome
#
# Initializing var.info slot.
#
# var.info slot initialized.

# %%
plot (chrom)
# Out:
# Plot with title “No SNP densities found”

# %%
chrom <- proc.chromR (chrom, verbose = TRUE)
options(warn = -1)
# Out:
# Nucleotide regions complete.
#
#   elapsed time:  1.585
#
# N regions complete.
#
#   elapsed time:  1.268
#
# Population summary complete.
#
#   elapsed time:  0.002
#
# window_init complete.
#
#   elapsed time:  0.001
#
# windowize_fasta complete.
#
#   elapsed time:  0.457
#
# windowize_variants complete.
#
#   elapsed time:  0.001

# %%
plot (chrom)
# Out:
# Plot with title “Variant count (per window)”

# %%
chromoqc(chrom , xlim=c(9e+05 , 30e+05))
# Out:
# Plot with title “SuperContig”

# %%
chromoqc(chrom , xlim=c(9e+05 , 30e+05))
# Out:
# Plot with title “SuperContig”
